# %% [markdown]
# ![Captura de tela em 2023-05-29 16-44-30.png](data:image/png;base64,...)

# %% [markdown]
# # Projeto
# *O problema do salva-vidas*

# %% [markdown]
# ## Equipe:
# 1.  Wanderson Faustino Patricio
# 1.  Francisco Anderson Maciel Cruz

# %% [markdown]
# ## Introdução

# %% [markdown]
# Recentemente, um acidente ocorrido na praia do Socorro colocou em evidência um problema até então ignorado.
# Um frequentador escapou com vida de uma situação de afogamento, após ter sido socorrido por um [salva-vidas](https://pt.wikipedia.org/wiki/Salva-vidas).
# O salvamento somente foi possível graças à grande experiência do salva-vidas que soube escolher a trajetória mais curta para alcançar a vítima em tempo hábil.
# Em entrevista logo após o acidente, ele revelou que a escolha da trajetória de salvamento depende de como está a correnteza naquele dia e do ponto de entrada no mar, pois isto pode aumentar ou diminuir o tempo gasto durante seu deslocamento pela praia e durante o trecho realizado a nado.
# Neste trabalho, vocês deverão determinar a melhor trajetória para o salva-vidas de modo que o tempo de salvamento seja o menor possível.

# %% [markdown]
# ## Hipóteses simplificadoras

# %% [markdown]
# O perfil típico da praia do Socorro obedece o padrão ilustrado abaixo, onde a praia média possui 50 metros de extensão.

# %% [markdown]
# ![perfil.png](data:image/png;base64,...)
#
# Fonte: [Olpe (2012)](http://siaibib01.univali.br/pdf/Carolina%20Alcantara%20Olpe.pdf)

# %% [markdown]
# Todo salva-vidas deve ser capaz de correr na praia a uma velocidade média de [$12{,}5$ m/s](https://pt.wikipedia.org/wiki/Usain_Bolt) e nadar no mar a $1{,}5$ m/s e [$2{,}5$ m/s](https://pt.wikipedia.org/wiki/Michael_Phelps) nas regiões de praia média e antepraia, respectivamente.

# %% [markdown]
# Suponham que a margem do oceano é fixa, definida pela reta $y = 0$, e que as vítimas estão localizadas em um ponto $V(x_V, -70)$, enquanto que o salva-vidas está posicionado em $S(x_S, 30)$.
# Denote por $P(x,0)$ e $P_2(y,-50)$ os pontos onde o salva-vidas adentra  na praia média e na antepraia, respectivamente.

# %% [markdown]
# ## Tarefas

# %% [markdown]
# _(a) Considerando $x_V = 0$ e $x_S = 80$, use a SymPy para definir uma função $T(x,y)$ que descreva o tempo total de salvamento._

# %%
import sympy as sp

x, y , T= sp.symbols('x y T')

T=sp.sqrt((80-x)**2+30**2)/12.5 + sp.sqrt((x-y)**2+50**2)/1.5 + sp.sqrt(y**2 + 20**2)/2.5

T
# Out:
# 0.4*sqrt(y**2 + 400) + 0.08*sqrt((80 - x)**2 + 900) + 0.666666666666667*sqrt((x - y)**2 + 2500)

# %% [markdown]
# *(b) Plote um gráfico 3D da superfície $z = T(x,y)$ usando a função [plot3d](https://docs.sympy.org/latest/modules/plotting.html#sympy.plotting.plot.plot3d).*

# %%
from sympy.plotting import plot3d

plot3d(T, (x, -100, 100), (y, -20, 20))

# %% [markdown]
# *(c) Plote um gráfico com curvas de nível $T(x,y) = c$, para $c \in \left\{ 0, 30, 60, 120, 150, 180\right\}$, usando a função [plot_implicit](https://docs.sympy.org/latest/modules/plotting.html#sympy.plotting.plot_implicit.plot_implicit).*

# %%
sp.plot_implicit(sp.Eq(T, 0), (x, -200, 200), (y, -200, 200))

# %%
sp.plot_implicit(sp.Eq(T, 30), (x, -200, 200), (y, -200, 200))

# %%
sp.plot_implicit(sp.Eq(T, 60), (x, -200, 200), (y, -200, 200))

# %%
sp.plot_implicit(sp.Eq(T, 120), (x, -300, 300), (y, -200, 200))

# %%
sp.plot_implicit(sp.Eq(T, 150), (x, -300, 300), (y, -300, 300))

# %%
sp.plot_implicit(sp.Eq(T, 180), (x, -400, 400), (y, -400, 400))

# %% [markdown]
# _(d) Utilize a função [solve](https://reliability.readthedocs.io/en/latest/Solving%20simultaneous%20equations%20with%20sympy.html) da SymPy para determinar a trajetória que corresponde ao tempo de salvamento mínimo. Ao final, plote o gráfico da trajetória calculada._

# %%
Tx = T.diff(x)

Tx
# Out:
# 0.08*(x - 80)/sqrt((80 - x)**2 + 900) + 0.666666666666667*(x - y)/sqrt((x - y)**2 + 2500)

# %%
Ty = T.diff(y)

Ty
# Out:
# 0.4*y/sqrt(y**2 + 400) + 0.666666666666667*(-x + y)/sqrt((x - y)**2 + 2500)

# %%
eq01 = sp.Eq(Tx-Ty, 0)
eq02 = sp.Eq(Ty, 0)

sp.solve([eq01,eq02],(x,y), domain = sp.S.Reals)
# Out:
# ---------------------------------------------------------------------------
# NonlinearError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sympy/core/relational.py in _eval_simplify(self, **kwargs)
#     441                     dif = r.lhs - r.rhs
# --> 442                     m, b = linear_coeffs(dif, x)
#     443                     if m.is_zero is False:
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solveset.py in linear_coeffs(eq, *syms, **_kw)
#    2486         return d  # default is still list but this won't matter
# -> 2487     raise NonlinearError('nonlinear term encountered: %s' % t)
#    2488
#
# NonlinearError: nonlinear term encountered: x**2*(2*x**2 - 3125)
#
# During handling of the above exception, another exception occurred:
#
# CoercionFailed                            Traceback (most recent call last)
# <ipython-input-99-b09e13596459> in <cell line: 4>()
#       2 eq02 = sp.Eq(Ty, 0)
#       3
# ----> 4 sp.solve([eq01,eq02],(x,y), domain = sp.S.Reals)
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1112         solution = _solve(f[0], *symbols, **flags)
#    1113     else:
# -> 1114         solution = _solve_system(f, symbols, **flags)
#    1115
#    1116     #
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1965                 for s in ok_syms:
#    1966                     try:
# -> 1967                         soln = _solve(eq2, s, **flags)
#    1968                     except NotImplementedError:
#    1969                         continue
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1416                 result = set()
#    1417                 break
# -> 1418             soln = _solve(m, symbol, **flags)
#    1419             result.update(set(soln))
#    1420         result = list(result)
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1759     if check:
#    1760         # keep only results if the check is not False
# -> 1761         result = [r for r in result if
#    1762                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1763     return result
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1760         # keep only results if the check is not False
#    1761         result = [r for r in result if
# -> 1762                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1763     return result
#    1764
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     308             # start over without the failed expanded form, possibly
#     309             # with a simplified solution
# --> 310             val = simplify(f.subs(sol))
#     311             if flags.get('force', True):
#     312                 val, reps = posify(val)
#
# /usr/local/lib/python3.10/dist-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     677                 # Do not apply doit on the segments as it has already
#     678                 # been done above, but simplify
# --> 679                 expr = piecewise_simplify(expr, deep=True, doit=False)
#     680                 # Still a Piecewise?
#     681                 if expr.has(Piecewise):
#
# /usr/local/lib/python3.10/dist-packages/sympy/functions/elementary/piecewise.py in piecewise_simplify(expr, **kwargs)
#    1302
#    1303 def piecewise_simplify(expr, **kwargs):
# -> 1304     expr = piecewise_simplify_arguments(expr, **kwargs)
#    1305     if not isinstance(expr, Piecewise):
#    1306         return expr
#
# /usr/local/lib/python3.10/dist-packages/sympy/functions/elementary/piecewise.py in piecewise_simplify_arguments(expr, **kwargs)
#    1279             e, c  = args[i]
#    1280             if isinstance(c, Basic):
# -> 1281                 c = simplify(c, **kwargs)
#    1282             args[i] = (e, c)
#    1283
#
# /usr/local/lib/python3.10/dist-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     599     _eval_simplify = getattr(expr, '_eval_simplify', None)
#     600     if _eval_simplify is not None:
# --> 601         return _eval_simplify(**kwargs)
#     602
#     603     original_expr = expr = collect_abs(signsimp(expr))
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/relational.py in _eval_simplify(self, **kwargs)
#     689     def _eval_simplify(self, **kwargs):
#     690         # standard simplify
# --> 691         e = super()._eval_simplify(**kwargs)
#     692         if not isinstance(e, Equality):
#     693             return e
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/relational.py in _eval_simplify(self, **kwargs)
#     455                     from sympy.polys.polytools import gcd, Poly, poly
#     456                     try:
# --> 457                         p = poly(dif, x)
#     458                         c = p.all_coeffs()
#     459                         constant = c[-1]
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in poly(expr, *gens, **args)
#    7293     opt = options.build_options(gens, args)
#    7294
# -> 7295     return _poly(expr, opt)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in _poly(expr, opt)
#    7277
#    7278                 if term.is_Number:
# -> 7279                     result = result.add(term)
#    7280                 else:
#    7281                     result = result.add(Poly._from_expr(term, opt))
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in add(f, g)
#    1443
#    1444         if not g.is_Poly:
# -> 1445             return f.add_ground(g)
#    1446
#    1447         _, per, F, G = f._unify(g)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in add_ground(f, coeff)
#    1280         """
#    1281         if hasattr(f.rep, 'add_ground'):
# -> 1282             result = f.rep.add_ground(coeff)
#    1283         else:  # pragma: no cover
#    1284             raise OperationNotSupported(f, 'add_ground')
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polyclasses.py in add_ground(f, c)
#     416     def add_ground(f, c):
#     417         """Add an element of the ground domain to ``f``. """
# --> 418         return f.per(dmp_add_ground(f.rep, f.dom.convert(c), f.lev, f.dom))
#     419
#     420     def sub_ground(f, c):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/domains/domain.py in convert(self, element, base)
#     449         if isinstance(element, Basic):
#     450             try:
# --> 451                 return self.from_sympy(element)
#     452             except (TypeError, ValueError):
#     453                 pass
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/domains/integerring.py in from_sympy(self, a)
#      62             return MPZ(int(a))
#      63         else:
# ---> 64             raise CoercionFailed("expected an integer, got %s" % a)
#      65
#      66     def get_field(self):
#
# CoercionFailed: expected an integer, got 9765625/8

# %% [markdown]
# 2023 Vicente Helano
# UFCA | Centro de Ciências e Tecnologia
